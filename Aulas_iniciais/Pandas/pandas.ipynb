# %% [markdown]
# # 📊Introdução ao Pandas

# %% [markdown]
# ## Objetivo
# Aprender a criar e manipular estruturas básicas do pandas, como DataFrame e Series

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as

# %% [markdown]
# ## Criando um DataFrame
# Aqui criamos um conjunto de dados simples  com nomes e idades

# %%
dados={"Nome": ["Jherika", "Pericles", "Nalva"],
       "Idade": [27,27,50]
}
df= pd.DataFrame(dados)
df
# Out:
#        Nome  Idade
# 0   Jherika     27
# 1  Pericles     27
# 2     Nalva     50

# %% [markdown]
# ## Resultado
# O DataFrame organiza os dados em formato de tabela, facilitando a vizualização e análise

# %% [markdown]
# ## Criando uma Series
# Uma series é uma estrutura de dados unidimensional

# %%
obj= pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %% [markdown]
# ## Explorando a Series
# Podemos acessar valores, índice e tipo dos dados

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ## Series com índice personalizado

# %%
obj2= pd.Series([4,7,-5,3], index=["d","b","a","c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='str')

# %%
obj2["a"]
# Out:
# np.int64(-5)

# %%
obj2["d"]= 6
obj2[["c", "a", "d"]]
# Out:
# c    3
# a   -5
# d    6
# dtype: int64

# %%
obj2[obj2 > 0]
# Out:
# d    6
# b    7
# c    3
# dtype: int64

# %%
obj2 * 2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %%
import numpy as np

# %%
np.exp(obj2)
# Out:
# d     403.428793
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
"b" in obj2
# Out:
# True

# %%
"e" in obj2
# Out:
# False

# %%
sdata= {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}

# %%
obj3= pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states=["California","Ohio", "Oregon", "Texas"]
obj4= pd.Series(sdata, index= states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.isna()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %% [markdown]
# ## ✅Conclusão
# Nesse estudo aprendi a criar DataFrames e Series utilizando pandas, além de entender como acessar seus valores e índices
# Essas estrtuturas são fundamentais para análise de dados em Python
